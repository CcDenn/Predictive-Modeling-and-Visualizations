# %%
import pandas as pd 
import numpy as np

# %%
df_original = pd.read_csv('Datasets/salarysample.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 734 entries, 0 to 741
# Data columns (total 45 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               734 non-null    int64
#  1   Job Title           734 non-null    object
#  2   Salary Estimate     734 non-null    object
#  3   Job Description     734 non-null    object
#  4   Rating              734 non-null    float64
#  5   Company Name        734 non-null    object
#  6   Location            734 non-null    object
#  7   Headquarters        734 non-null    object
#  8   Size                734 non-null    object
#  9   Founded             734 non-null    int64
#  10  Type of ownership   734 non-null    object
#  11  Industry            734 non-null    object
#  12  Sector              734 non-null    object
#  13  Revenue             734 non-null    object
#  14  Competitors         734 non-null    object
#  15  Hourly              734 non-null    int64
#  16  Employer provided   734 non-null    int64
#  17  Lower Salary        734 non-null    int64
#  18  Upper Salary        734 non-null    int64
#  19  Avg Salary(K)       734 non-null    float64
#  20  company_txt         734 non-null    object
#  21  Job Location        734 non-null    object
#  22  Age                 734 non-null    int64
#  23  Python              734 non-null    int64
#  24  spark               734 non-null    int64
#  25  aws                 734 non-null    int64
#  26  excel               734 non-null    int64
#  27  sql                 734 non-null    int64
#  28  sas                 734 non-null    int64
#  29  keras               734 non-null    int64
#  30  pytorch             734 non-null    int64
#  31  scikit              734 non-null    int64
#  32  tensor              734 non-null    int64
#  33  hadoop              734 non-null    int64
#  34  tableau             734 non-null    int64
#  35  bi                  734 non-null    int64
#  36  flink               734 non-null    int64
#  37  mongo               734 non-null    int64
#  38  google_an           734 non-null    int64
#  39  job_title_sim       734 non-null    object
#  40  seniority_by_title  734 non-null    object
#  41  Degree              734 non-null    object
#  42  Salary Cleaned      734 non-null    object
#  43  Minimum Salary      734 non-null    object
#  44  Maximum Salary      734 non-null    object
# dtypes: float64(2), int64(23), object(20)
# memory usage: 263.8+ KB

# %%
df= df_original
df.iloc[20:40]
# Out:
#     index                                 Job Title  \
# 20     20                            Data Scientist
# 21     21  Senior Data Scientist / Machine Learning
# 22     22             Data Scientist - Quantitative
# 23     23                            Data Scientist
# 24     25                            Data Scientist
# 25     26             Digital Health Data Scientist
# 26     27                            Data Scientist
# 27     28                    Associate Data Analyst
# 28     29                   Clinical Data Scientist
# 29     30                            Data Scientist
# 30     31                            Data Scientist
# 31     32                            Data Scientist
# 32     33  Data Scientist / Machine Learning Expert
# 33     34                            Data Scientist
# 34     35                            Data Scientist
# 35     36                          Web Data Analyst
# 36     37                            Data Scientist
# 37     38                            Data Scientist
# 38     39                     Senior Data Scientist
# 39     40                             Data Engineer
#
#                  Salary Estimate  \
# 20   $81K-$130K (Glassdoor est.)
# 21   $73K-$119K (Glassdoor est.)
# 22   $86K-$139K (Glassdoor est.)
# 23   $63K-$105K (Glassdoor est.)
# 24  $109K-$177K (Glassdoor est.)
# 25   $63K-$110K (Glassdoor est.)
# 26   $75K-$124K (Glassdoor est.)
# 27    $34K-$61K (Glassdoor est.)
# 28   $63K-$105K (Glassdoor est.)
# 29    $80K-$90K (Glassdoor est.)
# 30    $56K-$97K (Glassdoor est.)
# 31   $72K-$120K (Glassdoor est.)
# 32   $86K-$143K (Glassdoor est.)
# 33   $93K-$149K (Glassdoor est.)
# 34   $85K-$140K (Glassdoor est.)
# 35   $77K-$135K (Glassdoor est.)
# 36   $82K-$132K (Glassdoor est.)
# 37   $83K-$137K (Glassdoor est.)
# 38  $115K-$180K (Glassdoor est.)
# 39   $74K-$138K (Glassdoor est.)
#
#                                       Job Description  Rating  \
# 20  About Our Team\n\nWe understand that the first...     3.2
# 21  IMMEDIATE NEED FOR A SENIOR DATA SCIENTIST / M...     3.9
# 22  Truckstop.com is hiring a Data Scientist for o...     3.8
# 23  Position Summary\nOur Data Science team is cur...     4.3
# 24  Are you passionate about solving challenging p...     4.0
# 25  ROLE SUMMARY\n\nThe Digital Health Data Scient...     4.0
# 26  As the Enterprise Data and Analytics Center of...     3.5
# 27  Friday, January 17, 2020\n\nOur Enterprise Dat...     3.7
# 28  THIS ROLE MUST BE BASED IN SAN DIEGO\n\nAs par...     4.0
# 29  KnowBe4, Inc. is a high growth information sec...     4.8
# 30  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 31  Preferred Qualifications\nMasters degree or do...     3.6
# 32  Posting Title\nData Scientist / Machine Learni...     3.8
# 33  Title: Software Engineer, Data Science\n\nDesi...     3.8
# 34  New England Biolabs is seeking a Data Scientis...     4.7
# 35  We are looking for a Web Data Analyst to assis...     4.2
# 36  Overview\n\n\nAre you passionate about changin...     3.5
# 37  STR is a government research contractor specia...     4.7
# 38  Sartorius Stedim Data Analytics, a market lead...     3.5
# 39  Lancer Insurance Company is looking for a Data...     3.5
#
#                             Company Name        Location        Headquarters  \
# 20                            Porch\n3.2     Seattle, WA         Seattle, WA
# 21                        Health IQ\n3.9      Dallas, TX   Mountain View, CA
# 22                    Truckstop.com\n3.8     Chicago, IL    New Plymouth, ID
# 23                            SMC 3\n4.3  Louisville, KY  Peachtree City, GA
# 24                          Novetta\n4.0     Herndon, VA         Mc Lean, VA
# 25                           Pfizer\n4.0   Cambridge, MA        New York, NY
# 26  First Tech Federal Credit Union\n3.5   Hillsboro, OR        San Jose, CA
# 27      The Hanover Insurance Group\n3.7   Worcester, MA       Worcester, MA
# 28                           Pfizer\n4.0      Groton, CT        New York, NY
# 29                          KnowBe4\n4.8  Clearwater, FL      Clearwater, FL
# 30                             PNNL\n3.8    Richland, WA        Richland, WA
# 31                           Amrock\n3.6     Detroit, MI         Detroit, MI
# 32                         Novartis\n3.8   Cambridge, MA  Basel, Switzerland
# 33                 Juniper Networks\n3.8   Sunnyvale, CA       Sunnyvale, CA
# 34              New England Biolabs\n4.7     Ipswich, MA         Ipswich, MA
# 35                 Clarity Insights\n4.2    San Jose, CA         Chicago, IL
# 36                             Esri\n3.5    Redlands, CA        Redlands, CA
# 37    Systems & Technology Research\n4.7      Woburn, MA          Woburn, MA
# 38                        Sartorius\n3.5     Fremont, CA  Gottingen, Germany
# 39                 Lancer Insurance\n3.5  Long Beach, NY      Long Beach, NY
#
#              Size  Founded  ... tensor hadoop tableau bi flink  mongo  \
# 20     201 - 500      2012  ...      0      0       0  0     0      0
# 21     201 - 500      2013  ...      0      0       0  0     0      0
# 22    501 - 1000      1995  ...      0      0       0  0     0      1
# 23      51 - 200      1935  ...      0      0       1  0     0      0
# 24    501 - 1000      2012  ...      1      0       0  0     0      0
# 25        10000+      1849  ...      0      0       0  0     0      0
# 26   1001 - 5000      1952  ...      1      0       1  0     0      0
# 27  5001 - 10000      1852  ...      0      0       0  0     0      0
# 28        10000+      1849  ...      0      0       0  0     0      0
# 29    501 - 1000      2010  ...      0      0       0  0     0      0
# 30   1001 - 5000      1965  ...      0      0       0  0     0      0
# 31   1001 - 5000      1997  ...      0      0       0  0     0      0
# 32        10000+      1996  ...      0      0       0  0     0      0
# 33  5001 - 10000      1996  ...      1      0       0  0     0      1
# 34     201 - 500      1974  ...      0      0       0  0     0      0
# 35     201 - 500      2008  ...      0      0       1  1     0      0
# 36   1001 - 5000      1969  ...      0      1       1  0     0      1
# 37     201 - 500      2010  ...      1      1       0  0     0      0
# 38  5001 - 10000      1870  ...      0      0       0  0     0      0
# 39     201 - 500      1985  ...      0      0       0  0     0      0
#
#     google_an   job_title_sim  seniority_by_title  Degree
# 20          0  data scientist                  na       M
# 21          0  data scientist                  sr       P
# 22          0  data scientist                  na       M
# 23          0  data scientist                  na       M
# 24          0  data scientist                  na      na
# 25          0  data scientist                  na      na
# 26          0  data scientist                  na      na
# 27          0         analyst                  na      na
# 28          0  data scientist                  na       M
# 29          0  data scientist                  na       M
# 30          0  data scientist                  na      na
# 31          0  data scientist                  na       M
# 32          0  data scientist                  na      na
# 33          0  data scientist                  na       M
# 34          0  data scientist                  na      na
# 35          0         analyst                  na      na
# 36          0  data scientist                  na       M
# 37          0  data scientist                  na       P
# 38          0  data scientist                  sr       M
# 39          0   data engineer                  na       M
#
# [20 rows x 42 columns]

# %%
df = df_original

df.drop([177,177], axis=0, inplace=True)
df.drop([202,202], axis=0, inplace=True)
df.drop([357,357], axis=0, inplace=True)
df.drop([533,533], axis=0, inplace=True)
df.drop([711,711], axis=0, inplace=True)
df.drop([300,300], axis=0, inplace=True)
df.drop([45,45], axis=0, inplace=True)
df.drop([373,373], axis=0, inplace=True)

df['Salary Cleaned'] = df['Salary Estimate'].apply(lambda x: x.split('(')[0])
df['Minimum Salary'] = df['Salary Cleaned'].apply(lambda x: x.split('-')[0])
df['Maximum Salary'] = df['Salary Cleaned'].apply(lambda x: x.split('-')[1])

df['Minimum Salary'] = df['Minimum Salary'].str.replace('$','')
df['Minimum Salary'] = df['Minimum Salary'].str.replace('K','000')

df['Maximum Salary'] = df['Maximum Salary'].str.replace('$','')
df['Maximum Salary'] = df['Maximum Salary'].str.replace('K','000')

df[['Salary Estimate']].value_counts()
# Out:
# C:\Users\billg\AppData\Local\Temp\ipykernel_24996\675095372.py:16: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Minimum Salary'] = df['Minimum Salary'].str.replace('$','')
# C:\Users\billg\AppData\Local\Temp\ipykernel_24996\675095372.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Maximum Salary'] = df['Maximum Salary'].str.replace('$','')
# Salary Estimate
# $54K-$115K (Glassdoor est.)         6
# $49K-$113K (Glassdoor est.)         6
# $86K-$143K (Glassdoor est.)         6
# $76K-$142K (Glassdoor est.)         5
# $81K-$167K (Glassdoor est.)         5
#                                    ..
# $67K-$117K (Glassdoor est.)         1
# $67K-$119K (Glassdoor est.)         1
# $67K-$127K (Glassdoor est.)         1
# $21-$34 Per Hour(Glassdoor est.)    1
# $71K-$144K (Glassdoor est.)         1
# Length: 414, dtype: int64

# %%
df_cleaned = df.drop(columns={'index','Job Description','Rating','Company Name','Founded','Competitors','Hourly','Employer provided','Salary Cleaned','Minimum Salary','Lower Salary', 'Avg Salary(K)'})
df_cleaned['Upper Salary'].astype('float', errors='ignore')
# Out:
# 0       91.0
# 1      112.0
# 2       90.0
# 3       97.0
# 4      143.0
#        ...
# 737    111.0
# 738    133.0
# 739     91.0
# 740    160.0
# 741    126.0
# Name: Upper Salary, Length: 734, dtype: float64

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 734 entries, 0 to 741
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Job Title           734 non-null    object
#  1   Salary Estimate     734 non-null    object
#  2   Location            734 non-null    object
#  3   Headquarters        734 non-null    object
#  4   Size                734 non-null    object
#  5   Type of ownership   734 non-null    object
#  6   Industry            734 non-null    object
#  7   Sector              734 non-null    object
#  8   Revenue             734 non-null    object
#  9   Upper Salary        734 non-null    int64
#  10  company_txt         734 non-null    object
#  11  Job Location        734 non-null    object
#  12  Age                 734 non-null    int64
#  13  Python              734 non-null    int64
#  14  spark               734 non-null    int64
#  15  aws                 734 non-null    int64
#  16  excel               734 non-null    int64
#  17  sql                 734 non-null    int64
#  18  sas                 734 non-null    int64
#  19  keras               734 non-null    int64
#  20  pytorch             734 non-null    int64
#  21  scikit              734 non-null    int64
#  22  tensor              734 non-null    int64
#  23  hadoop              734 non-null    int64
#  24  tableau             734 non-null    int64
#  25  bi                  734 non-null    int64
#  26  flink               734 non-null    int64
#  27  mongo               734 non-null    int64
#  28  google_an           734 non-null    int64
#  29  job_title_sim       734 non-null    object
#  30  seniority_by_title  734 non-null    object
#  31  Degree              734 non-null    object
#  32  Maximum Salary      734 non-null    object
# dtypes: int64(18), object(15)
# memory usage: 195.0+ KB

# %%
df_cleaned = pd.get_dummies(df_cleaned)
df_cleaned
# Out:
#      Upper Salary  Age  Python  spark  aws  excel  sql  sas  keras  pytorch  \
# 0              91   48       1      0    0      1    0    1      0        0
# 1             112   37       1      0    0      0    0    0      0        0
# 2              90   11       1      1    0      1    1    1      0        0
# 3              97   56       1      0    0      0    0    0      0        0
# 4             143   23       1      0    0      1    1    1      0        0
# ..            ...  ...     ...    ...  ...    ...  ...  ...    ...      ...
# 737           111  191       0      0    1      0    0    0      0        0
# 738           133   15       1      1    1      0    1    0      0        0
# 739            91   37       0      0    0      1    0    0      0        0
# 740           160   -1       0      0    0      1    0    0      0        0
# 741           126   54       1      0    0      0    0    0      0        0
#
#      ...  Maximum Salary_89000   Maximum Salary_90000   Maximum Salary_91000   \
# 0    ...                      0                      0                      1
# 1    ...                      0                      0                      0
# 2    ...                      0                      1                      0
# 3    ...                      0                      0                      0
# 4    ...                      0                      0                      0
# ..   ...                    ...                    ...                    ...
# 737  ...                      0                      0                      0
# 738  ...                      0                      0                      0
# 739  ...                      0                      0                      1
# 740  ...                      0                      0                      0
# 741  ...                      0                      0                      0
#
#      Maximum Salary_92000   Maximum Salary_93000   Maximum Salary_95000   \
# 0                        0                      0                      0
# 1                        0                      0                      0
# 2                        0                      0                      0
# 3                        0                      0                      0
# 4                        0                      0                      0
# ..                     ...                    ...                    ...
# 737                      0                      0                      0
# 738                      0                      0                      0
# 739                      0                      0                      0
# 740                      0                      0                      0
# 741                      0                      0                      0
#
#      Maximum Salary_96000   Maximum Salary_97000   Maximum Salary_98000   \
# 0                        0                      0                      0
# 1                        0                      0                      0
# 2                        0                      0                      0
# 3                        0                      1                      0
# 4                        0                      0                      0
# ..                     ...                    ...                    ...
# 737                      0                      0                      0
# 738                      0                      0                      0
# 739                      0                      0                      0
# 740                      0                      0                      0
# 741                      0                      0                      0
#
#      Maximum Salary_99000
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ..                     ...
# 737                      0
# 738                      0
# 739                      0
# 740                      0
# 741                      0
#
# [734 rows x 1773 columns]

# %%
import pandas as pd
import numpy as np
import math
import sklearn.datasets
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

y_ = np.array(df_cleaned["Upper Salary"]).reshape(-1,1)
X_ = np.array(df_cleaned.drop(columns={"Upper Salary"}))
X_train_, X_test_, y_train_, y_test_ = train_test_split(X_, y_)

scaler_ = MinMaxScaler()
estimator_ = RandomForestRegressor(n_jobs=-1)
pipe_ = Pipeline(steps=[("scaler", scaler_), ("forest", estimator_)])

params_ = {'forest__max_depth':[5,6,7,8,9], 
            "forest__n_estimators":[75,100,125],
            "forest__max_features":[7,8,9,10,11,12,13,14]}
 
clf_ = GridSearchCV(pipe_, param_grid=params_, cv=3, n_jobs=-1) 
clf_.fit(X_train_, y_train_.ravel())
best_ = clf_.best_estimator_
print(best_.score(X_test_, y_test_))
print(best_)

ypred1 = best_.predict(X_test_)
print('RMSE:', mean_squared_error(ypred1, y_test_, squared=False))
# Out:
# 0.2583902651913248
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('forest',
#                  RandomForestRegressor(max_depth=9, max_features=14,
#                                        n_estimators=125, n_jobs=-1))])
# RMSE: 39.52534791087662

# %%
model1 = LinearRegression().fit(X_train_,y_train_)


r_sq = model1.score(X_test_, y_test_)
print('R-squared:', r_sq)

ypred = model1.predict(X_test_)
print('RMSE:', mean_squared_error(ypred, y_test_, squared=False))
# Out:
# R-squared: 0.8693142845126527
# RMSE: 16.59212650697999

# %%
df_cleaned2 = df.drop(columns={'index','Job Description','Rating','Company Name','Founded','Competitors','Hourly','Employer provided','Salary Cleaned','Minimum Salary','Upper Salary', 'Avg Salary(K)'})
df_cleaned2['Lower Salary'].astype('float', errors='ignore')
# Out:
# 0      53.0
# 1      63.0
# 2      80.0
# 3      56.0
# 4      86.0
#        ...
# 737    58.0
# 738    72.0
# 739    56.0
# 740    95.0
# 741    61.0
# Name: Lower Salary, Length: 734, dtype: float64

# %%
df_cleaned2 = pd.get_dummies(df_cleaned2)
df_cleaned2
# Out:
#      Lower Salary  Age  Python  spark  aws  excel  sql  sas  keras  pytorch  \
# 0              53   48       1      0    0      1    0    1      0        0
# 1              63   37       1      0    0      0    0    0      0        0
# 2              80   11       1      1    0      1    1    1      0        0
# 3              56   56       1      0    0      0    0    0      0        0
# 4              86   23       1      0    0      1    1    1      0        0
# ..            ...  ...     ...    ...  ...    ...  ...  ...    ...      ...
# 737            58  191       0      0    1      0    0    0      0        0
# 738            72   15       1      1    1      0    1    0      0        0
# 739            56   37       0      0    0      1    0    0      0        0
# 740            95   -1       0      0    0      1    0    0      0        0
# 741            61   54       1      0    0      0    0    0      0        0
#
#      ...  Maximum Salary_89000   Maximum Salary_90000   Maximum Salary_91000   \
# 0    ...                      0                      0                      1
# 1    ...                      0                      0                      0
# 2    ...                      0                      1                      0
# 3    ...                      0                      0                      0
# 4    ...                      0                      0                      0
# ..   ...                    ...                    ...                    ...
# 737  ...                      0                      0                      0
# 738  ...                      0                      0                      0
# 739  ...                      0                      0                      1
# 740  ...                      0                      0                      0
# 741  ...                      0                      0                      0
#
#      Maximum Salary_92000   Maximum Salary_93000   Maximum Salary_95000   \
# 0                        0                      0                      0
# 1                        0                      0                      0
# 2                        0                      0                      0
# 3                        0                      0                      0
# 4                        0                      0                      0
# ..                     ...                    ...                    ...
# 737                      0                      0                      0
# 738                      0                      0                      0
# 739                      0                      0                      0
# 740                      0                      0                      0
# 741                      0                      0                      0
#
#      Maximum Salary_96000   Maximum Salary_97000   Maximum Salary_98000   \
# 0                        0                      0                      0
# 1                        0                      0                      0
# 2                        0                      0                      0
# 3                        0                      1                      0
# 4                        0                      0                      0
# ..                     ...                    ...                    ...
# 737                      0                      0                      0
# 738                      0                      0                      0
# 739                      0                      0                      0
# 740                      0                      0                      0
# 741                      0                      0                      0
#
#      Maximum Salary_99000
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ..                     ...
# 737                      0
# 738                      0
# 739                      0
# 740                      0
# 741                      0
#
# [734 rows x 1773 columns]

# %%
y_ = np.array(df_cleaned2["Lower Salary"]).reshape(-1,1)
X_ = np.array(df_cleaned2.drop(columns={"Lower Salary"}))
X_train_, X_test_, y_train_, y_test_ = train_test_split(X_, y_)

scaler_ = MinMaxScaler()
estimator_ = RandomForestRegressor(n_jobs=-1)
pipe_ = Pipeline(steps=[("scaler", scaler_), ("forest", estimator_)])

params_ = {'forest__max_depth':[5,6,7,8,9], 
            "forest__n_estimators":[75,100,125],
            "forest__max_features":[7,8,9,10,11,12,13,14]}
 
clf_ = GridSearchCV(pipe_, param_grid=params_, cv=3, n_jobs=-1) 
clf_.fit(X_train_, y_train_.ravel())
best_ = clf_.best_estimator_
print(best_.score(X_test_, y_test_))
print(best_)

ypred1 = best_.predict(X_test_)
print('RMSE:', mean_squared_error(ypred1, y_test_, squared=False))
# Out:
# 0.25930229286154927
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('forest',
#                  RandomForestRegressor(max_depth=9, max_features=14,
#                                        n_jobs=-1))])
# RMSE: 24.588581335282516

# %%
model1 = LinearRegression().fit(X_train_,y_train_)


r_sq = model1.score(X_test_, y_test_)
print('R-squared:', r_sq)

ypred = model1.predict(X_test_)
print('RMSE:', mean_squared_error(ypred, y_test_, squared=False))
# Out:
# R-squared: 0.7529273633514902
# RMSE: 14.20120828558829
